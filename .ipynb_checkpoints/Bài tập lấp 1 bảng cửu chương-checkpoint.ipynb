# %%
for i in range(1,10):
    for j in range(1,11):
        print(f"Bảng cửu chương {i} : {i:2} *{j:2} = {i*j:2}")
# Out:
# Bảng cửu chương 1 :  1 * 1 =  1
# Bảng cửu chương 1 :  1 * 2 =  2
# Bảng cửu chương 1 :  1 * 3 =  3
# Bảng cửu chương 1 :  1 * 4 =  4
# Bảng cửu chương 1 :  1 * 5 =  5
# Bảng cửu chương 1 :  1 * 6 =  6
# Bảng cửu chương 1 :  1 * 7 =  7
# Bảng cửu chương 1 :  1 * 8 =  8
# Bảng cửu chương 1 :  1 * 9 =  9
# Bảng cửu chương 1 :  1 *10 = 10
# Bảng cửu chương 2 :  2 * 1 =  2
# Bảng cửu chương 2 :  2 * 2 =  4
# Bảng cửu chương 2 :  2 * 3 =  6
# Bảng cửu chương 2 :  2 * 4 =  8
# Bảng cửu chương 2 :  2 * 5 = 10
# Bảng cửu chương 2 :  2 * 6 = 12
# Bảng cửu chương 2 :  2 * 7 = 14
# Bảng cửu chương 2 :  2 * 8 = 16
# Bảng cửu chương 2 :  2 * 9 = 18
# Bảng cửu chương 2 :  2 *10 = 20
# Bảng cửu chương 3 :  3 * 1 =  3
# Bảng cửu chương 3 :  3 * 2 =  6
# Bảng cửu chương 3 :  3 * 3 =  9
# Bảng cửu chương 3 :  3 * 4 = 12
# Bảng cửu chương 3 :  3 * 5 = 15
# Bảng cửu chương 3 :  3 * 6 = 18
# Bảng cửu chương 3 :  3 * 7 = 21
# Bảng cửu chương 3 :  3 * 8 = 24
# Bảng cửu chương 3 :  3 * 9 = 27
# ...
